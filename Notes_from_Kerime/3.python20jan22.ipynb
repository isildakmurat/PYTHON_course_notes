# %%
değişken = 10

# %%
print(değişken)
# Out:
# 10

# %%
değişken = değişken + 1  #  değişkenleri kullanarak böyle matematiksel işlemler yapabilirsin
print(değişken)
# Out:
# 11

# %%
değişken = değişken + 1
print(değişken)
# Out:
# 12

# %%
değişken2 = 5

# %%
değişken2 = değişken2 * 2
print(değişken2)
# Out:
# 10

# %%
değişken2 = değişken2 * 2
print(değişken2)
# Out:
# 20

# %%
print(değişken)
# Out:
# 12

# %%
değişken += 1    # değişken = değişken+1  ile   değ += 1 aynıdır
print(değişken)
# Out:
# 13

# %%
değişken2 *= 2
print(değişken2)
# Out:
# 40

# %%
a = 8
b = 2 

a += b 
print(a)
# Out:
# 10

# %%
a *= b
print(a)
# Out:
# 20

# %%
a = (1 + 3) ** (2 ** (1*2 / 2) / 2)
print(a)
# Out:
# 4.0

# %%
a = 3
b = 4
c = (a ** 2 + b ** 2) ** 0.5
print(c)
# Out:
# 5.0

# %%
print("ali")   # varsayılan olarak tanımlı sep=( ) olduğu için print içinde 
               #virgülle ayrılarak yan yana yazılmış değerleri boşlukla ayırır
print("deli", "veli")
print("selvi", "baharat", 44)
print(c, False, "ahmet", 3.44)
# Out:
# ali
# deli veli
# selvi baharat 44
# 5.0 False ahmet 3.44

# %%
print(c, False, "ahmet", 3.14, sep = "-")  # sep = kullanarak " " içine ne koyarsan seperatör o olur
# Out:
# 5.0-False-ahmet-3.14

# %%
print(c, False, "ahmet", 3.14, sep = "%")
# Out:
# 5.0%False%ahmet%3.14

# %%
print(c, False, "ahmet", 3.14, sep = "#")
# Out:
# 5.0#False#ahmet#3.14

# %%
print("ali", end = " ")  # end = kullanarak " " içine ne koyarsak satırı öyle bitirir
print("veli", "ayşe")    # bişey yapmazsak da aşağı iner. çünkü end = "\n" tanımlı
# Out:
# ali veli ayşe

# %%
print(2 ** 4)
# Out:
# 16

# %%
print('Ahmet\'in ceketi')  # ters slash kendinden sonra gelenin sihrini alır
# Out:
# Ahmet'in ceketi

# %%
print('Ahmet\in ceketi')  #önünde bir sihir olmadığı için normal kabul etti
# Out:
# Ahmet\in ceketi

# %%
print('Ayla\nın çantası')   #\n new line demek olduğu için alt satıra geçirir
# Out:
# Ayla
# ın çantası

# %%
print('Ayla\\nın çantası')  # yanına bir daha ters slash koyarsak new line emrinin sihrini alır
# Out:
# Ayla\nın çantası

# %%
True and True and True  # hepsi True ise sonuç olarak son True'yu çıkarır
# Out:
# True

# %%
1 and 2 and 3
# Out:
# 3

# %%
bool (None)  # değeri olmayan şeyler False'tır
# Out:
# False

# %%
bool("0")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
0 and None and 1  #ilk False'ı alır
# Out:
# 0

# %%
True or True or True #ilk true'yu alır
# Out:
# True

# %%
False or False or False #son false'u alır
# Out:
# False

# %%
0 or None or ""
# Out:
# ''

# %%
0 or 1 or 2 or ""  # karışık olunca da ilk True'yu alır
# Out:
# 1

# %%
not 0
# Out:
# True

# %% [markdown]
# The Strength of Strings in Python

# %%
string_karakterler = "&% , ali deli veli-1234"
print(string_karakterler)
print(string_karakterler[0])  # ilk index numarası sıfırdır. saymaya sıfırdan başlıyoruz
# Out:
# &% , ali deli veli-1234
# &

# %%
"clarus"[5]
# Out:
# 's'

# %%
okul = "clarus"
print(okul[5])
# Out:
# s

# %%
okul[2:4]  # start:stop yani iki indexinden başla 4 indexini görünce dur ( 4 indexi dahil değil)
# Out:
# 'ar'

# %%
okul[:3]  # starta bir şey demediği için sıfırdan başla üçü görünce dur demek
# Out:
# 'cla'

# %%
okul[:]  #ne starta ne de stpoa bir şey demediği için alayına gider
# Out:
# 'clarus'
