# %%
my_age = 33  # değişkene isim veirirken boşluk değil, alt tre kullan
your_age = 30  # değişkene isim verirken anlamlı ve anlaşılır olsun
my_age = your_age  # değişkene ikinci kez değer vererek güncelledik
print(my_age)
# Out:
# 30

# %%
# değişken isminde başta rakam kullanılmaz
# normal tre kullanılmaz
# özel karakter (!,?,&,@...) kullanılmaz
# değişkend tırnak içinde (string) olmaz

# %%
# bazı iyi variable isim örnekleri
print("""prime_list
prime_no
list_prime
num_prime""")
# Out:
# prime_list
# prime_no
# list_prime
# num_prime

# %%
x = y = z = "same"  # birden fazla değişkene aynı değeri atayabiliriz
print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %%
jan = mar = may = jul = aug = oct = dec = 31
apr = jun = sept = nov = 30
feb = 28
print(jan, feb, mar, apr, may, jun, jul, aug, sept, oct, nov, dec)
# Out:
# 31 28 31 30 31 30 31 31 30 31 30 31

# %%
walter = None  # değişkenlere sonradan değer atamak için None değerini verebiliriz
print(walter)
# Out:
# None

# %%
a = 11  #değişkenin değeri en sonda ne yazıldığya odur
b = 22
c = 44

a = 33
b = 55
c = a
print(a, b, c,)
# Out:
# 33 55 33

# %%
a, b, c = 5, 3.2, "hello"  # aralara virgül koyarak çoklu değişken ve değer ataması
print(a)
print(b)
print(c)
# Out:
# 5
# 3.2
# hello

# %%
# data type'lara geldik
type("alivelideli")
# Out:
# str

# %%
type(a)  #31 numara'daki
# Out:
# int

# %%
10.5 #float
# Out:
# 10.5

# %%
10 == 10.0 #integer da olsa float da olsa rakamsal değeri aynı
# Out:
# True

# %%
float(0)
# Out:
# 0.0

# %%
"10" #string
10 #integer
10.0 #float
# Out:
# 10.0

# %%
type(0.0)
# Out:
# float

# %%
int("10")
# Out:
# 10

# %%
a = int("11")
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
str(3.14)
# Out:
# '3.14'

# %%
str(False)
# Out:
# 'False'

# %%
int(3.14)
# Out:
# 3

# %%
float(11)
# Out:
# 11.0

# %%
float("11")
# Out:
# 11.0

# %%
float("33.33")
# Out:
# 33.33

# %%
x = 39
v = "11"
y = "2.5"
z = "I am at_"
print(x-int(v))
print(x-float(y)) 
print(z+str(x))
# Out:
# 28
# 36.5
# I am at_39

# %%
"33" + "11"  # iki stringi yan yana koyup topla dersen sadece yan yana koyar
# Out:
# '3311'

# %%
33 + 11  # integerlarda ise matematiksel işlemi yapar
# Out:
# 44

# %%
"35"*3  #string ile çarpma işlemi yaparsan tekrar eder
# Out:
# '353535'

# %%
"33" + 11 # error verir
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-c22480491b9f> in <module>()
# ----> 1 "33" + 11 # error verir
#
# TypeError: can only concatenate str (not "int") to str

# %%
#area of the circle
pi = 3.14
r = 5
area = pi * r**2  

print(area)
# Out:
# 78.5
