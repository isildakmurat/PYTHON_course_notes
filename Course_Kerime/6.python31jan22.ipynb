# %%
["ali", "veli", "deli"]  # bu bir listedir
# Out:
# ['ali', 'veli', 'deli']

# %%
list("clarusway")  # bu da bir listedir, elemanlarına ayrılabilen (iterable) değerler alabilir
                # iterable'ı elemanlarına ayırır, aralarına virgül koyar 
                # ve her bir elemanı listenin elemanları haline getirir
# Out:
# ['c', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y']

# %%
a = [1, 2, 3]

# %%
list(a)
# Out:
# [1, 2, 3]

# %%
list(1234)  #hata verir, sebebi çin aşağıyı kontrol et
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c1ee5a6a3775> in <module>()
# ----> 1 list(1234)  #hata verir, sebebi çin aşağıyı kontrol et
#
# TypeError: 'int' object is not iterable

# %%
len(1230)  #hata verir çünkü len fonksiyonu da eterable alır
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8f8f7f0ef280> in <module>()
# ----> 1 len(1230)
#
# TypeError: object of type 'int' has no len()

# %%
mesela = [[1,2,4,], False, "Ali", 11, ["veli", ["deli"]]]
 # listler farklı veri tipleri alır
 # köşeli parantez içindekiler de ayrı birer eleman olarak alınır

# %%
len(mesela)
# Out:
# 5

# %%
len([[[" "]]])
# Out:
# 1

# %%
len([[[" ",1,3]]])
# Out:
# 1

# %%
boş = []
print(boş)
# Out:
# []

# %%
boş2 = list()
print(boş2)
# Out:
# []

# %%
[]
# Out:
# []

# %%
"ali deli veli".  #nokta koyup beklersen orada metodları çıkarır

# %%
listem = []
listem.append(11)  # liste değişti. 
listem
# Out:
# [11]

# %%
a = "ali deli veli"
a.replace("i", "+")  # HATIRLA burada a değişkeni değişmezdi
# Out:
# 'al+ del+ vel+'

# %%
print(a)
# Out:
# ali deli veli

# %%
listem.append(22)
print(listem)
# Out:
# [11, 22]

# %%
listem.append(33)
print(listem)
# Out:
# [11, 22, 33]

# %%
gardaşlar = ["ali", "deli"]

# %%
gardaşlar.append("veli")
print(gardaşlar)
# Out:
# ['ali', 'deli', 'veli']

# %%
gardaşlar.append(True)
gardaşlar
# Out:
# ['ali', 'deli', 'veli', True]

# %%
gardaşlar.append(3.14)  # append metodu ile yalnızca bir eleman ekleyebilirsin
print(gardaşlar)
# Out:
# ['ali', 'deli', 'veli', True, 3.14]

# %%
gardaşlar.pop()  #en sondan eleman siler ve çıktı olarak sildiği elemanı verir. 
                 # değişkenin çıktısını tekrar çıktı alarak elemanın silindiğini görebiliriz
# Out:
# 3.14

# %%
print(gardaşlar)
# Out:
# ['ali', 'deli', 'veli', True]

# %%
gardaşlar.pop()
# Out:
# True

# %%
gardaşlar
# Out:
# ['ali', 'deli', 'veli']

# %%
gardaşlar.pop(1)  # sırardan birinci elemanı sildi (sıfırdan başladı)
# Out:
# 'deli'

# %%
gardaşlar
# Out:
# ['ali', 'veli']

# %%
gardaşlar.insert(1, "deli")  # bir numaralı indexe deliyi ekledik

# %%
print(gardaşlar)
# Out:
# ['ali', 'deli', 'veli']

# %%
sayılar = [1, 2, 3, 4]

# %%
sayılar.insert(3, 5)  # üç numaralı indexse 5 atıyoruz

# %%
sayılar
# Out:
# [1, 2, 3, 5, 4]

# %%
sayılar = [1, 2, 3, 4]

# %%
sayılar.insert(4, 5)  # dört numaralı indexe 5i atadık 
                      # dörtten büyük ne dersek diyelim sona atardı
sayılar
# Out:
# [1, 2, 3, 4, 5]

# %%
mesela # yukarıda önceden tanımladığımız bir değişken
# Out:
# [[1, 2, 4], False, 'Ali', 11, ['veli', ['deli']]]

# %%
mesela.remove([1, 2, 4])  # mesela değişkeninden bir elemanı çıkardık

# %%
mesela  #böyle oldu
# Out:
# [False, 'Ali', 11, ['veli', ['deli']]]

# %%
yeni = [3,5,1,7,4]

# %%
yeni.sort() # kalıcı olarak listeyi sıraya sokar

# %%
yeni
# Out:
# [1, 3, 4, 5, 7]

# %%
eski = ["behçet", "cavidan", "ali", "deli", "veli"]

# %%
eski.sort()  #kalıcı olarak alfabetik sıraya koyar

# %%
eski
# Out:
# ['ali', 'behçet', 'cavidan', 'deli', 'veli']

# %%
list_1 = ["one", "four", "nine"]

# %%
list_1.sort()

# %%
list_1
# Out:
# ['four', 'nine', 'one']

# %%
list_1.sort(reverse=True)

# %%
list_1
# Out:
# ['one', 'nine', 'four']

# %%
list_2 = ["@", "*-", "False"]

# %%
list_2.sort()

# %%
list_2
# Out:
# ['*-', '@', 'False']

# %%
ord("*")  # yıldızın ascıı code'da sırasını gösterir
# Out:
# 42

# %%
ord("@")
# Out:
# 64

# %%
ord("F")
# Out:
# 70

# %%
list_3 = [True, False]

# %%
list_3.sort()

# %%
list_3  # False'u sıfır kabul ettiğimiz için önce False gelir
# Out:
# [False, True]

# %%
ord("1")
# Out:
# 49

# %%
list_4 = [[3], [44], [-12]]  # listenin içindeki listenin elemanlarına göre sıralr

# %%
list_4.sort()

# %%
list_4
# Out:
# [[-12], [3], [44]]

# %%
list_5 = [[1, 3], [44, -40], [-12, 1]]

# %%
list_5.sort()  # ilk elemanları baz alarak sıralar

# %%
list_5
# Out:
# [[-12, 1], [1, 3], [44, -40]]

# %%
70
# Out:
# 70

# %%
chr(70)  # integer olan bir unikodu string temsili ne ise ona götürrü
# Out:
# 'F'

# %%
ord("F")
# Out:
# 70

# %%
chr(443)
# Out:
# 'ƻ'
