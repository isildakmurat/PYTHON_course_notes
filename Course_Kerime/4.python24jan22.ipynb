# %%
city = "phoenix"
city
# Out:
# 'phoenix'

# %%
city[-2]  # eksi yönden indexlemek, eksi yönde 0dan değil 1den başlar
# Out:
# 'i'

# %%
city[5]
# Out:
# 'i'

# %%
city[1:5]
# Out:
# 'hoen'

# %%
city[-6:-2]  # eksi indexler arası çağırdığımızda yine soldan sağa okur
# Out:
# 'hoen'

# %%
city[1:-3]
# Out:
# 'hoe'

# %%
city[-7:4]
# Out:
# 'phoe'

# %%
city[::-1]  # burada start ve stopa bir şey demedik, geri geri git dedik
# Out:
# 'xineohp'

# %%
city[-2:-6]  # bu şekilde giderek aradığını bulamayacağı için boş verir
# Out:
# ''

# %%
city[-2:-6:-1]  # bu indexlerde ancak geriden gelerek bulur
# Out:
# 'ineo'

# %%
city[2:6:-1]
# Out:
# ''

# %%
len(city)  # uzunluğu çıkarır
# Out:
# 7

# %%
len("371")
# Out:
# 3

# %%
len("0")
# Out:
# 1

# %%
len("1 1")  # boşluğu da sayar
# Out:
# 3

# %%
len(111)  #integer olduğu için
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-93cd539acb93> in <module>()
# ----> 1 len(111)
#
# TypeError: object of type 'int' has no len()

# %%
sonuç = str((5 + 6) ** 2) + "121"  #matematiksel işlemleri integer olarak hesaplayıp string olarak dışarı çıkardık
sonuç
# Out:
# '121121'

# %%
"ali" + "deli" + "veli"  #stinglerle toplama yaparasan böyle olur
# Out:
# 'alideliveli'

# %%
"100" + "500" + "001"
# Out:
# '100500001'

# %%
sonuç = (sonuç + sonuç) * 2
sonuç
# Out:
# '121121121121121121121121'

# %%
"ali" * 3
# Out:
# 'alialiali'

# %%
string_1 = 'I am angry'
print(* string_1)
# Out:
# I   a m   a n g r y

# %%
string_2 = '1453'
print(* string_2)
# Out:
# 1 4 5 3

# %%
print(* "joseph@clarusway.com")
# Out:
# j o s e p h @ c l a r u s w a y . c o m

# %%
len(" ")
# Out:
# 1

# %%
a = "ali"
b = "deli"
a = a + b 
a
# Out:
# 'alideli'

# %% [markdown]
# format metodu

# %%
deneme = "clarusway"

# %%
deneme.format()
# Out:
# 'clarusway'

# %%
saat = "05:00"
yer = "okul"
miktar = 2

# %%
"Ben sabah {} de uyandım. {} 'a gittim. Gelirken de {} kilo elma aldım.".format(saat, yer, miktar)
# Out:
# "Ben sabah 05:00 de uyandım. okul 'a gittim. Gelirken de 2 kilo elma aldım."

# %%
"Ben sabah {} de uyandım. {} 'a gittim. Gelirken de {} kilo elma aldım.".format("05:00", "Okul", 2)
# Out:
# "Ben sabah 05:00 de uyandım. Okul 'a gittim. Gelirken de 2 kilo elma aldım."

# %%
"Ben sabah {saat} de uyandım. {yer} 'a gittim. Gelirken de {miktar} kilo elma aldım.".format(yer = "Okul", miktar = 2, saat = "05:00")
# Out:
# "Ben sabah 05:00 de uyandım. Okul 'a gittim. Gelirken de 2 kilo elma aldım."

# %%
"Ben sabah {1} de uyandım. {0} 'a gittim. Gelirken de {2} kilo elma aldım.".format("Okul", "05:00", 2)
# Out:
# "Ben sabah 05:00 de uyandım. Okul 'a gittim. Gelirken de 2 kilo elma aldım."
